# %% [markdown]
# ## Importations

# %%
import pandas as pd
import numpy as np
from rank_bm25 import BM25Okapi
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import os
import torch

# %% [markdown]
# ## Dataset Preprocessing

# %%
# Load the datasets

df_review = pd.read_csv('data/reviews83325.csv')
df_place = pd.read_csv('data/Tripadvisor.csv')
df_subcategorie = pd.read_csv('data/AttractionSubCategorie.csv')
df_subtype = pd.read_csv('data/AttractionSubType.csv')
df_cuisine = pd.read_csv('data/cuisine.csv')
df_restaurant_type = pd.read_csv('data/restaurantType.csv')

# Preprocess the data - Merging Reviews and Places
if not os.path.exists('data/review_place.csv'):

    # Select only english reviews
    df_review = df_review[df_review['langue'] == 'en'].copy()

    # Select only the first 100 reviews for each place to limit the dataset size
    df_review_100 = df_review.groupby('idplace').head(100)

    cols_eval = [
        'id', 
        'nom', 
        'typeR', # Level 1 Evaluation
        'restaurantTypeCuisine', # Level 2 Evaluation (Restaurants)
        'activiteSubCategorie', # Level 2 Evaluation (Attractions)
        'restaurantType',
        'activiteType'
    ]

    df_place = pd.read_csv('data/Tripadvisor.csv', usecols=cols_eval)
    df_review_place = pd.merge(df_review_100, df_place, left_on='idplace', right_on='id')
    # df_review_place = df_review_place.drop(columns=['id'])

    # Cleaning the merged dataset before saving it
    df_review_place = df_review_place.dropna(subset=['review'])
    df_review_place.to_csv('data/review_place.csv', index=False)
else:
    df_review_place = pd.read_csv('data/review_place.csv')
# Out:
# C:\Users\Thomas\AppData\Local\Temp\ipykernel_18528\407371976.py:3: DtypeWarning: Columns (15,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_review = pd.read_csv('data/reviews83325.csv')

# %% [markdown]
# ## Dataset split between database (user requests) and results

# %%
import numpy as np

# Get unique place IDs
unique_places = df_review_place['idplace'].unique()

# Shuffling places to ensure random distribution between train and test sets
np.random.seed(42)
np.random.shuffle(unique_places)

# Divide the places into 2 sets: 50% for training and 50% for testing
split_idx = len(unique_places) // 2
train_ids = unique_places[:split_idx]
test_ids = unique_places[split_idx:]

print(f"Total number of place : {len(unique_places)}")
print(f"Places in databse (Train) : {len(train_ids)}")
print(f"Places used as requests (Test) : {len(test_ids)}")

# DataFrame creation
df_train = df_review_place[df_review_place['idplace'].isin(train_ids)].copy()
df_test = df_review_place[df_review_place['idplace'].isin(test_ids)].copy()

# Aggregation of reviews by place
train_grouped = df_train.groupby('idplace').agg({
    'review': lambda x: " ".join(x.astype(str)),
    'typeR': 'first',
    'restaurantTypeCuisine': 'first',
    'activiteSubCategorie': 'first',
    'nom': 'first',
    'activiteType': 'first'
}).reset_index()

test_grouped = df_test.groupby('idplace').agg({
    'review': lambda x: " ".join(x.astype(str)),
    'typeR': 'first',
    'restaurantTypeCuisine': 'first',
    'activiteSubCategorie': 'first',
    'nom': 'first',
    'activiteType': 'first'
}).reset_index()

print("Aggregation completed.")
# Out:
# Total number of place : 1835
# Places in databse (Train) : 917
# Places used as requests (Test) : 918
# Aggregation completed.

# %% [markdown]
# ## Baseline Setup : BM25

# %%
# Tokenization and BM25 Implementation
corpus_tokenized = [doc.lower().split(" ") for doc in train_grouped['review'].tolist()]

# BM25 model initialization
bm25 = BM25Okapi(corpus_tokenized)

# Research function using BM25
def recherche_bm25(query_text, top_n=10):
    # Query tokenization
    tokenized_query = query_text.lower().split(" ")
    
    # Similarity scoring using BM25
    doc_scores = bm25.get_scores(tokenized_query)
    
    # Get the indices of the top N scores
    top_indices = np.argsort(doc_scores)[-top_n:][::-1]
    
    # Return the top N results with their scores
    results = []
    for idx in top_indices:
        results.append({
            'idplace': train_grouped.iloc[idx]['idplace'],
            'nom': train_grouped.iloc[idx]['nom'],
            'score': doc_scores[idx],
            'typeR': train_grouped.iloc[idx]['typeR'],
            'restaurantTypeCuisine': train_grouped.iloc[idx]['restaurantTypeCuisine'],
            'activiteType': train_grouped.iloc[idx]['activiteType']
        })
    return results

# Test example : we take the reviews of the first place in the TEST set
test_query = test_grouped.iloc[0]['review']
print(f"Search for places : {test_grouped.iloc[0]['nom']}\nQuest : {test_query[:100]}...")

resultats = recherche_bm25(test_query)
for r in resultats[:3]:
    print(f"-> Recommended : {r['nom']} (Score: {r['score']:.2f})")
# Out:
# Search for places : Place des Vosges
# Quest : Personally I think it is the most beautiful square of Paris. Well maintained and the area around it ...
# -> Recommended : Le Marais  (Score: 12304.89)
# -> Recommended : Maison de Victor Hugo (Score: 12203.08)
# -> Recommended : Carette (Score: 11824.91)

# %% [markdown]
# ## SBERT Encoding + Cosine Similarity

# %%
# Model loading
# 'all-MiniLM-L6-v2' is fast and very effective for similarity tasks
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2') 

# Embedding creation for the search database (Train)
print("Database encoding (Train)...")
train_sentences = train_grouped['review'].tolist()
train_embeddings = model.encode(train_sentences, show_progress_bar=True, convert_to_tensor=True)

# SBERT recommendation function
def recommander_sbert(query_text, top_n=10):
    # Query encoding (the reviews of the test place)
    query_embedding = model.encode([query_text], convert_to_tensor=True)
    
    # Cosine similarity is computed on CPU for compatibility with sklearn
    cos_scores = cosine_similarity(query_embedding.cpu(), train_embeddings.cpu())[0]
    
    # Get the indices of the top N scores
    top_indices = np.argsort(cos_scores)[-top_n:][::-1]
    
    results = []
    for idx in top_indices:
        results.append({
            'idplace': train_grouped.iloc[idx]['idplace'],
            'nom': train_grouped.iloc[idx]['nom'],
            'score': cos_scores[idx],
            'typeR': train_grouped.iloc[idx]['typeR'], # Useful for evaluation
            'restaurantTypeCuisine': train_grouped.iloc[idx]['restaurantTypeCuisine'],
            'activiteType': train_grouped.iloc[idx]['activiteType']
        })
    return results

# Test rapide
test_query = test_grouped.iloc[0]['review']
print(f"\Query for : {test_grouped.iloc[0]['nom']}")
recommandations = recommander_sbert(test_query, top_n=3)

for i, res in enumerate(recommandations):
    print(f"{i+1}. {res['nom']} - Score: {res['score']:.4f}")
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 653.31it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Database encoding (Train)...
# Batches: 100%|██████████| 29/29 [00:14<00:00,  1.97it/s]
# \Query for : Place des Vosges
# 1. Cathédrale Notre-Dame de Paris - Score: 0.7167
# 2. Maison de Victor Hugo - Score: 0.7025
# 3. Hotel de Nice - Score: 0.6735

# %% [markdown]
# ## Evaluation Metrics

# %%
def calculate_ranking_error(test_row, recommendations, level=1):
    """
    Compute the ranking error for a single test place based on the first relevant match in the recommendations.
    level 1: matching on typeR
    level 2: matching on cuisine ou activiteSubCategorie
    """
    for rank, rec in enumerate(recommendations):
        match = False
        
        if level == 1:
            # Simple matching on the type (H, R, A, AP)
            if rec['typeR'] == test_row['typeR']:
                match = True
        
        elif level == 2:
            print("Rec", rec)
            # Matching on subCategorie (Cuisine or Activity)
            query_cat = str(test_row['restaurantTypeCuisine']) + " " + str(test_row['activiteSubCategorie'])
            rec_cat = str(rec['restaurantTypeCuisine']) + " " + str(rec['activiteType'])
            
            # Cleaning and splitting into sets for comparison
            q_set = set(query_cat.lower().replace(',', ' ').split())
            r_set = set(rec_cat.lower().replace(',', ' ').split())
            
            if not q_set.isdisjoint(r_set) and 'nan' not in q_set:
                match = True
                
        if match:
            return rank  # Return the rank of the first relevant match
            
    return len(recommendations) # If no match found in the top N, we consider the error as N (worst case)

# --- BOUCLE D'ÉVALUATION GLOBALE ---

erreurs_bm25_l1 = []
erreurs_sbert_l1 = []

print("Evaluating on sample...")

# We are testing on a sample to go faster, or the whole set
sample_test = test_grouped.sample(min(100, len(test_grouped))) 

for _, row in sample_test.iterrows():
    # Get recommendations for the current test place
    recs_bm25 = recherche_bm25(row['review'], top_n=50)
    # For SBERT, we reuse the typeR/cuisine columns added in the previous step
    recs_sbert = recommander_sbert(row['review'], top_n=50)
    
    # Compute Level 2 errors
    erreurs_bm25_l1.append(calculate_ranking_error(row, recs_bm25, level=2))
    erreurs_sbert_l1.append(calculate_ranking_error(row, recs_sbert, level=2))

print(f"\n--- RESULT LEVEL 2 ERROR ---")
print(f"Mean Error BM25 : {np.mean(erreurs_bm25_l1):.2f}")
print(f"Mean Error SBERT : {np.mean(erreurs_sbert_l1):.2f}")
# Out:
# Evaluating on sample...
# Rec {'idplace': np.int64(1724980), 'nom': 'Suan Thai', 'score': np.float64(699.2299283358575), 'typeR': 'R', 'restaurantTypeCuisine': '10659,10660,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(718063), 'nom': 'Isami Zushi', 'score': np.float32(0.6827014), 'typeR': 'R', 'restaurantTypeCuisine': '5473,10659,10653', 'activiteType': None}
# Rec {'idplace': np.int64(11482945), 'nom': 'Accès prioritaire au sommet de la tour Eiffel et hôte', 'score': np.float64(438.26307904674644), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(12467083), 'nom': 'Billet coupe-file\xa0: excursion à la tour Eiffel et accès au sommet par l’ascenseur ', 'score': np.float32(0.6855728), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11473941), 'nom': 'Tour Eiffel, Louvre, Notre Dame: Paris à vélo en petit groupe', 'score': np.float64(1315.1615847452838), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11764621), 'nom': 'Centre de Paris ainsi que Notre-Dame\xa0: Balade privée avec guide', 'score': np.float32(0.7642001), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11453877), 'nom': "Billet coupe-file\xa0: Visite du musée du Louvre et du musée d'Orsay", 'score': np.float64(275.9637605579735), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(16654137), 'nom': 'Secrets & Mystères du Louvre | Billets coupe-file et XSmall Group (6 max)', 'score': np.float32(0.82220304), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(12467083), 'nom': 'Billet coupe-file\xa0: excursion à la tour Eiffel et accès au sommet par l’ascenseur ', 'score': np.float64(624.3809811730301), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11452641), 'nom': 'Visite guidée de Paris en petit groupe le soir', 'score': np.float32(0.7631111), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(5608013), 'nom': "L'Etiquette", 'score': np.float64(104.55333356968643), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(14861605), 'nom': 'LA Dégustation Ultime de Vin et de Fromage (10 fromages, 10 vins)', 'score': np.float32(0.7594445), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(1035226), 'nom': 'Le Brise Miche', 'score': np.float64(159.9223773608584), 'typeR': 'R', 'restaurantTypeCuisine': '10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(17205831), 'nom': 'Spring Sushi', 'score': np.float32(0.73875415), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11460122), 'nom': 'Cours de cuisine à Paris avec déjeuner 3 plats, vin, option marché', 'score': np.float64(191.75208568109574), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(15217448), 'nom': 'Visitez un marché et cuisinez avec un fin gourmet', 'score': np.float32(0.7393114), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(8633320), 'nom': 'Bijoux Blues', 'score': np.float64(1003.5758802842136), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(13282515), 'nom': 'Souvenirs mémorables de Paris\xa0: créez votre propre bijou de luxe', 'score': np.float32(0.6913515), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(239650), 'nom': 'Auberge de Jeunesse MIJE  Fourcy', 'score': np.float64(19886.854592052394), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(4776710), 'nom': 'Le 1er Etage Marais', 'score': np.float32(0.7674552), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11482945), 'nom': 'Accès prioritaire au sommet de la tour Eiffel et hôte', 'score': np.float64(16585.648275141833), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(18912883), 'nom': 'Visite de la Tour Eiffel au 1er et 2ème étage avec accès au sommet à Paris', 'score': np.float32(0.651985), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(8450883), 'nom': 'Georges Abstraction Surface Air', 'score': np.float64(18024.220966215573), 'typeR': 'R', 'restaurantTypeCuisine': '10654,5086', 'activiteType': None}
# Rec {'idplace': np.int64(719116), 'nom': "Le Flore en l'Ile", 'score': np.float32(0.7034674), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10683,10665', 'activiteType': None}
# Rec {'idplace': np.int64(1755379), 'nom': 'Brasserie Les Deux Palais', 'score': np.float64(2157.7455457287056), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10640,10654,10665,10992', 'activiteType': None}
# Rec {'idplace': np.int64(7085708), 'nom': 'Les petites bouchees', 'score': np.float32(0.65568125), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10655,10648,10665,10697,10992', 'activiteType': None}
# Rec {'idplace': np.int64(1938733), 'nom': 'Chez Margot', 'score': np.float64(51.7392663049108), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10683,10665', 'activiteType': None}
# Rec {'idplace': np.int64(808712), 'nom': 'La Chaise au Plafond', 'score': np.float32(0.798164), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(11473256), 'nom': "Jardins et sépulture de Monet à Giverny: visite d'une demi-journée en petit groupe", 'score': np.float64(386.1260509827344), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13571421), 'nom': 'Visite de Giverny et Versailles au départ de Paris avec déjeuner', 'score': np.float32(0.63881797), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(17472770), 'nom': 'City Sightseeing Paris Officiel: Ligne Rouge (24h)', 'score': np.float64(396.3267636001037), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11449348), 'nom': "Transfert privé à l'arrivée de Paris: Charles de Gaulle ou Orly", 'score': np.float32(0.65729296), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6276150), 'nom': "Just'in Paris", 'score': np.float64(260.21407896704676), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(17223765), 'nom': 'Visite privée du Marché d’Aligre à Paris et dégustation', 'score': np.float32(0.65601075), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(1335758), 'nom': 'Akash', 'score': np.float64(3609.151952691018), 'typeR': 'R', 'restaurantTypeCuisine': '10346,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(2221999), 'nom': 'Metropolitain', 'score': np.float32(0.67199534), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11457682), 'nom': 'Visite guidée privée et billet coupe-file\xa0: Musée du Louvre Musée du Louvre', 'score': np.float64(864.5186224186706), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13203190), 'nom': 'Visite privée du Musée d’Orsay - billet coupe-file et guide local expérimenté', 'score': np.float32(0.6180241), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11450391), 'nom': 'Spectacle au Moulin Rouge à Paris', 'score': np.float64(1603.9372809372), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11988017), 'nom': 'Billet Paris Crazy Horse Cabaret avec option de surclassement au champagne', 'score': np.float32(0.7469591), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(1024865), 'nom': 'Pozzetto', 'score': np.float64(686.2101885260986), 'typeR': 'R', 'restaurantTypeCuisine': '4617,10666', 'activiteType': None}
# Rec {'idplace': np.int64(3696326), 'nom': 'Bistrot Le Louis IX', 'score': np.float32(0.72351646), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10640,10654', 'activiteType': None}
# Rec {'idplace': np.int64(11473256), 'nom': "Jardins et sépulture de Monet à Giverny: visite d'une demi-journée en petit groupe", 'score': np.float64(131.05469160912992), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(12923666), 'nom': 'Excursion d’une journée complète au château de Versailles et à la maison de Claude\xa0Monet à Giverny au départ de Paris', 'score': np.float32(0.58062106), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(1207588), 'nom': 'La Belle Hortense', 'score': np.float64(79.0671924207129), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10682', 'activiteType': None}
# Rec {'idplace': np.int64(2173597), 'nom': 'Melodies Graphiques', 'score': np.float32(0.56193423), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(532331), 'nom': 'Maison européenne de la photographie', 'score': np.float64(285.7600953498152), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11487060), 'nom': 'Séance photo portraits', 'score': np.float32(0.774178), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(718729), 'nom': 'Sherry Butt', 'score': np.float64(98.56384665197373), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(1335548), 'nom': 'Zebaar', 'score': np.float32(0.71837246), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(7336999), 'nom': 'Yummy & Guiltfree Temple', 'score': np.float64(242.63632236999865), 'typeR': 'R', 'restaurantTypeCuisine': '10617,10665,10992', 'activiteType': None}
# Rec {'idplace': np.int64(1946135), 'nom': 'Nectarine', 'score': np.float32(0.6112802), 'typeR': 'R', 'restaurantTypeCuisine': '5086', 'activiteType': None}
# Rec {'idplace': np.int64(6673413), 'nom': 'Homies', 'score': np.float64(2000.952512581311), 'typeR': 'R', 'restaurantTypeCuisine': '10671,10749,10648,10665', 'activiteType': None}
# Rec {'idplace': np.int64(12328805), 'nom': 'Ici', 'score': np.float32(0.5867757), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10621,10682,10642', 'activiteType': None}
# Rec {'idplace': np.int64(4451713), 'nom': 'Hanoi', 'score': np.float64(1287.1083317247317), 'typeR': 'R', 'restaurantTypeCuisine': '10659,10675,10665', 'activiteType': None}
# Rec {'idplace': np.int64(13387881), 'nom': 'Chez Ajia', 'score': np.float32(0.71855056), 'typeR': 'R', 'restaurantTypeCuisine': '10659,10696,10665,10697,10992', 'activiteType': None}
# Rec {'idplace': np.int64(11446386), 'nom': 'Billet coupe-file pour le musée du Louvre et audio-guide', 'score': np.float64(65.93674836693707), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(14070767), 'nom': 'Sautez la ligne Paris Catacombs Tour', 'score': np.float32(0.6108673), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446379), 'nom': 'Visite de Paris avec Chambord, Chenonceau et dégustations de vins', 'score': np.float64(245.8979335385728), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(316641), 'nom': 'Hotel Bastille Speria', 'score': np.float32(0.6910607), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11446387), 'nom': "Paris à Versailles et excursion d'une journée à Giverny avec déjeuner au bord de l'Epte", 'score': np.float64(1206.171005620101), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(16862124), 'nom': 'Visite en petit groupe de champagne au départ de Paris avec caves de Reims et dégustation de champagne', 'score': np.float32(0.7439159), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6276150), 'nom': "Just'in Paris", 'score': np.float64(9408.564513634368), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(14011180), 'nom': 'Balade à Montmartre\xa0: Le meilleur de l’art, de la culture et de la gastronomie à Paris', 'score': np.float32(0.65186524), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446379), 'nom': 'Visite de Paris avec Chambord, Chenonceau et dégustations de vins', 'score': np.float64(15629.185890693429), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13286604), 'nom': 'Excursion privée Monet et Van Gogh de Paris à Giverny, Auvers sur Oise', 'score': np.float32(0.7138248), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(3371621), 'nom': 'Au Petit Versailles Du Marais', 'score': np.float64(8740.183452000538), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(8454258), 'nom': 'Valentina Bakery', 'score': np.float32(0.722698), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11988650), 'nom': 'Visite privée à pied de 3 heures de Paris et de Montmartre', 'score': np.float64(853.6511005731256), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11448681), 'nom': 'Excursions de pâtisserie et de Chocolat à Paris', 'score': np.float32(0.71815497), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6078937), 'nom': 'Charlemagne et ses leudes', 'score': np.float64(77.76186812371697), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(14178491), 'nom': 'Fontaines de la Place des Vosges', 'score': np.float32(0.6150152), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(2613395), 'nom': 'Paris by Mouth', 'score': np.float64(747.8042933960137), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(18911162), 'nom': 'Faits saillants et joyaux cachés de la Sainte Chapelle: visite privée de la ville', 'score': np.float32(0.78541124), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(718729), 'nom': 'Sherry Butt', 'score': np.float64(744.4794788847078), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(1035550), 'nom': 'The Auld Alliance Pub', 'score': np.float32(0.7547635), 'typeR': 'R', 'restaurantTypeCuisine': '10640,10662,10670,10745', 'activiteType': None}
# Rec {'idplace': np.int64(292257), 'nom': 'Le Marais ', 'score': np.float64(218.99815887090264), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(235555), 'nom': 'Castex Hotel', 'score': np.float32(0.7091894), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(8087200), 'nom': 'Huygens', 'score': np.float64(948.6132869989422), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(9464720), 'nom': 'Le Peloton Cafe', 'score': np.float32(0.61774683), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10665', 'activiteType': None}
# Rec {'idplace': np.int64(11455997), 'nom': 'Visite de dégustation de nourriture en petit groupe à Paris Montmartre', 'score': np.float64(1440.8839465040378), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(15054934), 'nom': 'Visite gastronomique de Montmartre', 'score': np.float32(0.6663919), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(194223), 'nom': 'Hotel de Nice', 'score': np.float64(30843.631368239), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11452639), 'nom': "Balade à Montmartre centrée sur l'art avec billet coupe-file pour le Musée d'Orsay", 'score': np.float32(0.6068255), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11473256), 'nom': "Jardins et sépulture de Monet à Giverny: visite d'une demi-journée en petit groupe", 'score': np.float64(7181.699974758557), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13282431), 'nom': 'Visite guidée avec billet coupe-file pour Versailles et Giverny, au départ de Paris', 'score': np.float32(0.61162055), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(12463809), 'nom': 'Billet coupe-file et visite guidée des catacombes de Paris', 'score': np.float64(405.7437080638202), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(14920429), 'nom': 'La grande escale de Paris: le meilleur de Paris en un jour!', 'score': np.float32(0.7289032), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6276150), 'nom': "Just'in Paris", 'score': np.float64(2371.69045328663), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(12033205), 'nom': "Excursion d'une journée en petit groupe à Giverny et à Versailles au départ de Paris", 'score': np.float32(0.56713915), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(292257), 'nom': 'Le Marais ', 'score': np.float64(177.468046074134), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11454713), 'nom': 'Visite à pied du quartier de la Bastille à Paris pour une dégustation de produits alimentaires', 'score': np.float32(0.6191292), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(587896), 'nom': 'Grand Hotel du Loiret', 'score': np.float64(31100.507194116093), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(6617874), 'nom': 'Hôtel Dupond-Smith', 'score': np.float32(0.680547), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(1596020), 'nom': 'Au Bouquet St. Paul', 'score': np.float64(1100.5766681883592), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10665', 'activiteType': None}
# Rec {'idplace': np.int64(2342792), 'nom': 'Comme A Lisbonne', 'score': np.float32(0.80784804), 'typeR': 'R', 'restaurantTypeCuisine': '10654,10680,10665', 'activiteType': None}
# Rec {'idplace': np.int64(1724980), 'nom': 'Suan Thai', 'score': np.float64(476.9134223460274), 'typeR': 'R', 'restaurantTypeCuisine': '10659,10660,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(1035638), 'nom': 'Kiccho', 'score': np.float32(0.59530157), 'typeR': 'R', 'restaurantTypeCuisine': '5473,10653,10659,10665', 'activiteType': None}
# Rec {'idplace': np.int64(587896), 'nom': 'Grand Hotel du Loiret', 'score': np.float64(30756.26102295057), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(5551034), 'nom': "D'win Hotel", 'score': np.float32(0.8000959), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11458418), 'nom': "Macaron de Paris: cours en petit groupe avec option d'avance", 'score': np.float64(2165.8472283083315), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11458417), 'nom': 'Croissant de Paris faisant de la classe en petit groupe', 'score': np.float32(0.426749), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11469157), 'nom': 'Croisière sur la Seine avec dîner et musique en direct', 'score': np.float64(15368.861701862266), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11469157), 'nom': 'Croisière sur la Seine avec dîner et musique en direct', 'score': np.float32(0.6921612), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(15040216), 'nom': "Visite guidée de la tour Eiffel par ascenseur avec surclassement en option pour l'accès au sommet", 'score': np.float64(461.1721644082662), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(17771120), 'nom': 'Segway tour Capital sites ', 'score': np.float32(0.6584922), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(2362966), 'nom': 'Le Pick-Clops', 'score': np.float64(1030.446399621967), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10640,10642,10665', 'activiteType': None}
# Rec {'idplace': np.int64(16869418), 'nom': 'Monville Paris', 'score': np.float32(0.7671044), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10671,10679,10665', 'activiteType': None}
# Rec {'idplace': np.int64(11446387), 'nom': "Paris à Versailles et excursion d'une journée à Giverny avec déjeuner au bord de l'Epte", 'score': np.float64(1891.0441438634348), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(15340595), 'nom': 'Visite à pied de Montmartre avec un guide local privé', 'score': np.float32(0.70667243), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6673413), 'nom': 'Homies', 'score': np.float64(1047.3404516461578), 'typeR': 'R', 'restaurantTypeCuisine': '10671,10749,10648,10665', 'activiteType': None}
# Rec {'idplace': np.int64(4757439), 'nom': 'Sly Bar', 'score': np.float32(0.7753687), 'typeR': 'R', 'restaurantTypeCuisine': '10670', 'activiteType': None}
# Rec {'idplace': np.int64(195459), 'nom': 'Maison de Victor Hugo', 'score': np.float64(15187.647654507064), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(188679), 'nom': 'Cathédrale Notre-Dame de Paris', 'score': np.float32(0.7012162), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11482945), 'nom': 'Accès prioritaire au sommet de la tour Eiffel et hôte', 'score': np.float64(2400.040541724401), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13004066), 'nom': "Paris avec billet coupe-file à la visite guidée de l'Arc de Triomphe", 'score': np.float32(0.70043314), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(2542620), 'nom': 'Little Cafe', 'score': np.float64(1671.5122284437982), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10640,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(3420074), 'nom': 'Le Reveil Bastille', 'score': np.float32(0.61925447), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654', 'activiteType': None}
# Rec {'idplace': np.int64(1035629), 'nom': 'Sorza', 'score': np.float64(14115.794905947572), 'typeR': 'R', 'restaurantTypeCuisine': '4617,5086,10649,10654,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(8653135), 'nom': 'Le Chanard', 'score': np.float32(0.6770625), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(8452359), 'nom': 'Une Glace a Paris', 'score': np.float64(5052.914257124763), 'typeR': 'R', 'restaurantTypeCuisine': '5086', 'activiteType': None}
# Rec {'idplace': np.int64(4465505), 'nom': 'De Neuville', 'score': np.float32(0.62837625), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(2227687), 'nom': 'Studio des Parfums', 'score': np.float64(1022.3835194911959), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(16823169), 'nom': 'Séance photo à Paris pour familles et couples (30 minutes)', 'score': np.float32(0.7357122), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(4927124), 'nom': "Bear's Den", 'score': np.float64(839.2871324788216), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(4757439), 'nom': 'Sly Bar', 'score': np.float32(0.60662305), 'typeR': 'R', 'restaurantTypeCuisine': '10670', 'activiteType': None}
# Rec {'idplace': np.int64(11457682), 'nom': 'Visite guidée privée et billet coupe-file\xa0: Musée du Louvre Musée du Louvre', 'score': np.float64(5866.814399403843), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13181348), 'nom': 'Balade privée dans le Marais et le quartier juif à Paris', 'score': np.float32(0.72617495), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11458418), 'nom': "Macaron de Paris: cours en petit groupe avec option d'avance", 'score': np.float64(81.67038940043344), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(16749305), 'nom': 'Excursion d’une demi-journée en side-car Ural d’époque\xa0: le meilleur de Paris (3\xa0heures)', 'score': np.float32(0.57553566), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11481196), 'nom': 'Excursion privée à la journée en Champagne, au départ de Paris', 'score': np.float64(909.753335101873), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(13286604), 'nom': 'Excursion privée Monet et Van Gogh de Paris à Giverny, Auvers sur Oise', 'score': np.float32(0.7449386), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11469157), 'nom': 'Croisière sur la Seine avec dîner et musique en direct', 'score': np.float64(18962.40862838773), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446423), 'nom': 'Dîner-croisière sur la Seine et spectacle du Moulin Rouge', 'score': np.float32(0.715358), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11469157), 'nom': 'Croisière sur la Seine avec dîner et musique en direct', 'score': np.float64(4424.9128441009825), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(19080770), 'nom': 'La Chamade', 'score': np.float32(0.60787475), 'typeR': 'R', 'restaurantTypeCuisine': '10654,5086', 'activiteType': None}
# Rec {'idplace': np.int64(2261934), 'nom': 'Le Jaja', 'score': np.float64(6132.265149921783), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665,10992', 'activiteType': None}
# Rec {'idplace': np.int64(1840021), 'nom': 'Le Perchoir du Dome', 'score': np.float32(0.6961119), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(2010582), 'nom': 'Le Comptoir des Mers', 'score': np.float64(1479.9942318263825), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10643', 'activiteType': None}
# Rec {'idplace': np.int64(1787161), 'nom': 'Cafe Med', 'score': np.float32(0.7799605), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(782264), 'nom': 'Kyo', 'score': np.float64(4750.691803303599), 'typeR': 'R', 'restaurantTypeCuisine': '5473,10653,10659,10665', 'activiteType': None}
# Rec {'idplace': np.int64(17205831), 'nom': 'Spring Sushi', 'score': np.float32(0.6851402), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(11449817), 'nom': 'Faites une visite guidée du château et des jardins de Versailles au départ de Paris', 'score': np.float64(4685.610922731261), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11449348), 'nom': "Transfert privé à l'arrivée de Paris: Charles de Gaulle ou Orly", 'score': np.float32(0.64794695), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(6276150), 'nom': "Just'in Paris", 'score': np.float64(3372.700401910286), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(14054395), 'nom': 'Excursion pâtisserie de Paris', 'score': np.float32(0.7459958), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(17577142), 'nom': 'Dîner privé: un dîner gastronomique avec accords mets et vins', 'score': np.float64(578.2559839119832), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(17577142), 'nom': 'Dîner privé: un dîner gastronomique avec accords mets et vins', 'score': np.float32(0.77012384), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446425), 'nom': "Excursion d'une journée à Giverny et Versailles en petit groupe, au départ de Paris", 'score': np.float64(411.57775417471555), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446387), 'nom': "Paris à Versailles et excursion d'une journée à Giverny avec déjeuner au bord de l'Epte", 'score': np.float32(0.8353978), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(4521132), 'nom': 'La Cerise sur la Pizza - Saint Paul', 'score': np.float64(443.92577354247834), 'typeR': 'R', 'restaurantTypeCuisine': '4617,10641,10665,10697', 'activiteType': None}
# Rec {'idplace': np.int64(13142894), 'nom': 'Pizza e  Fichi', 'score': np.float32(0.77916664), 'typeR': 'R', 'restaurantTypeCuisine': '4617,10640,10641,10642,10649,10670', 'activiteType': None}
# Rec {'idplace': np.int64(16860563), 'nom': "Visite privée romantique de Paris Montmartre et jeu d'exploration de la ville", 'score': np.float64(1934.4720151335887), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11452641), 'nom': 'Visite guidée de Paris en petit groupe le soir', 'score': np.float32(0.7480922), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(7336999), 'nom': 'Yummy & Guiltfree Temple', 'score': np.float64(391.91568185449677), 'typeR': 'R', 'restaurantTypeCuisine': '10617,10665,10992', 'activiteType': None}
# Rec {'idplace': np.int64(11447965), 'nom': 'Billet coupe-file\xa0: Hard Rock Cafe de Paris avec repas ', 'score': np.float32(0.60960495), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(3371621), 'nom': 'Au Petit Versailles Du Marais', 'score': np.float64(983.0522579293742), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(2405629), 'nom': 'Florence Kahn Bakery and Delicatessen', 'score': np.float32(0.70654285), 'typeR': 'R', 'restaurantTypeCuisine': '10654,10666,10742,10769,10665,10768', 'activiteType': None}
# Rec {'idplace': np.int64(11473253), 'nom': "Tour du Mont Saint Michel avec entrée de l'abbaye et dégustation de cidre", 'score': np.float64(3951.6249392564596), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(18274806), 'nom': 'Visite guidée du débarquement en Normandie en petit groupe au départ de Paris', 'score': np.float32(0.6189617), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11474503), 'nom': "Visite touristique de Paris en side-car rétro, excursion personnalisée d'une journée complète en option", 'score': np.float64(20801.00643811193), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(14011180), 'nom': 'Balade à Montmartre\xa0: Le meilleur de l’art, de la culture et de la gastronomie à Paris', 'score': np.float32(0.68418205), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11457682), 'nom': 'Visite guidée privée et billet coupe-file\xa0: Musée du Louvre Musée du Louvre', 'score': np.float64(2135.700419181329), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11453879), 'nom': 'Balade historique dans Paris et visite guidée privée du musée du Louvre', 'score': np.float32(0.7760126), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11446379), 'nom': 'Visite de Paris avec Chambord, Chenonceau et dégustations de vins', 'score': np.float64(1765.3575094036764), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(18923711), 'nom': 'Bienvenue à Paris', 'score': np.float32(0.72175837), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(719073), 'nom': 'Le Chant des Voyelles', 'score': np.float64(2777.4612264038606), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(1062071), 'nom': 'Le Bistrot de la Place', 'score': np.float32(0.75287104), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10665', 'activiteType': None}
# Rec {'idplace': np.int64(17681773), 'nom': 'Paris by Night', 'score': np.float64(2234.998632285874), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(12465008), 'nom': "Coupe file d'attente, visite guidée privée du musée du Louvre", 'score': np.float32(0.661996), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(2613395), 'nom': 'Paris by Mouth', 'score': np.float64(7186.442308815503), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(12648609), 'nom': 'Dégustation de vins et de fromages d’une journée dans la vallée de la Loire au départ de Paris', 'score': np.float32(0.723639), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(239641), 'nom': "Hotel de la Herse d'Or", 'score': np.float64(28733.15228269346), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(316641), 'nom': 'Hotel Bastille Speria', 'score': np.float32(0.74147797), 'typeR': 'H', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(1596020), 'nom': 'Au Bouquet St. Paul', 'score': np.float64(13615.621970898777), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10665', 'activiteType': None}
# Rec {'idplace': np.int64(808712), 'nom': 'La Chaise au Plafond', 'score': np.float32(0.80040026), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(2362966), 'nom': 'Le Pick-Clops', 'score': np.float64(2288.4222699898883), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10640,10642,10665', 'activiteType': None}
# Rec {'idplace': np.int64(8021972), 'nom': 'Legay Choc', 'score': np.float32(0.5856667), 'typeR': 'R', 'restaurantTypeCuisine': '5086', 'activiteType': None}
# Rec {'idplace': np.int64(13395476), 'nom': 'Visite de Paris avec arrêts multiples', 'score': np.float64(9951.629559536172), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11449348), 'nom': "Transfert privé à l'arrivée de Paris: Charles de Gaulle ou Orly", 'score': np.float32(0.7059408), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11458417), 'nom': 'Croissant de Paris faisant de la classe en petit groupe', 'score': np.float64(24065.2063869869), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(808712), 'nom': 'La Chaise au Plafond', 'score': np.float32(0.7067434), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(6276150), 'nom': "Just'in Paris", 'score': np.float64(115.05257602196181), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11452641), 'nom': 'Visite guidée de Paris en petit groupe le soir', 'score': np.float32(0.6689841), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(786885), 'nom': 'Cafe Hugo', 'score': np.float64(15693.180820712558), 'typeR': 'R', 'restaurantTypeCuisine': '5086,10642,10654,10665', 'activiteType': None}
# Rec {'idplace': np.int64(1336696), 'nom': 'Le Bobar', 'score': np.float32(0.688063), 'typeR': 'R', 'restaurantTypeCuisine': None, 'activiteType': None}
# Rec {'idplace': np.int64(1847871), 'nom': 'Pont de la Tournelle', 'score': np.float64(1160.7553484033895), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(10377984), 'nom': 'Pont Notre Dame', 'score': np.float32(0.74826014), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11449817), 'nom': 'Faites une visite guidée du château et des jardins de Versailles au départ de Paris', 'score': np.float64(538.37952715467), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11731068), 'nom': 'Ban Sabai Bastille', 'score': np.float32(0.47193465), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11453183), 'nom': 'Paris à pied en petit groupe', 'score': np.float64(923.5933839517734), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(15016681), 'nom': 'Paris Rive Gauche: visite guidée privée et historique de Paris', 'score': np.float32(0.7839007), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(2425619), 'nom': 'Le Double Fond', 'score': np.float64(761.2806103586589), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(5043639), 'nom': 'Association Pour la Sauvegarde et la Mise en Valeur du Paris Historique', 'score': np.float32(0.55067724), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11449278), 'nom': 'Visite de Paris en Segway', 'score': np.float64(356.70352712438773), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(17771120), 'nom': 'Segway tour Capital sites ', 'score': np.float32(0.8347603), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(2613395), 'nom': 'Paris by Mouth', 'score': np.float64(6014.268442432412), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
# Rec {'idplace': np.int64(11449852), 'nom': 'Excursion en petit groupe avec dégustation de vins en Champagne, au départ de Paris', 'score': np.float32(0.7524736), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(11455418), 'nom': 'Tour à vélo des secrets de Paris', 'score': np.float64(712.5156506053117), 'typeR': 'AP', 'restaurantTypeCuisine': None, 'activiteType': 'attractionproduct'}
# Rec {'idplace': np.int64(10089740), 'nom': 'Movies in Motion', 'score': np.float32(0.7901263), 'typeR': 'A', 'restaurantTypeCuisine': None, 'activiteType': 'attraction'}
#
# --- RESULT LEVEL 2 ERROR ---
# Mean Error BM25 : 0.00
# Mean Error SBERT : 0.00
